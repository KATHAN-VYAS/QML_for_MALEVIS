# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
import os

# ==========================================
# ### DYNAMIC CLASS LOADING ###
# ==========================================

# Path config - Trying the 'test' folder first, falling back to 'val' if needed
# Based on your previous absolute paths, I've added the /home/netsec1/ prefix
TEST_PATH_1 = '/home/netsec1/Kathan/MaleVis 2 dataset/malevis_train_val_300x300/test'
TEST_PATH_2 = '/home/netsec1/Kathan/MaleVis 2 dataset/malevis_train_val_300x300/val'

def get_class_names(path_list):
    for path in path_list:
        if os.path.exists(path):
            print(f"Found dataset at: {path}")
            # Get all subdirectories and sort them alphabetically
            classes = sorted([d for d in os.listdir(path) if os.path.isdir(os.path.join(path, d))])
            return classes, path
    return [], None

class_names, loaded_path = get_class_names([TEST_PATH_1, TEST_PATH_2])



# ==========================================
# ### DATA ENTRY SECTION ###
# ==========================================

model_names = ['Basic QML', 'QNI-CCP', 'QSLP']

# Data from your snippet (25 rows)
fgsm_data = [
    [0.84, 0.80, 1.00], # Adialer.C / Adposhel ?
    [0.00, 0.01, 0.65], # Agent.FYI
    [0.13, 0.04, 0.72], # Allaple.A
    [0.00, 0.02, 0.93], # Allaple.L
    [0.02, 0.00, 0.76], # Alueron.gen!J
    [0.02, 0.00, 0.77], # Autorun.K
    [0.01, 0.34, 0.77], # C2LOP.P
    [0.19, 0.00, 0.92], # C2LOP.gen!g
    [0.01, 0.14, 0.97], # Dialplatform.B
    [0.04, 0.00, 0.35], # Dontovo.A
    [0.00, 0.20, 1.00], # Fakerean
    [0.00, 0.00, 1.00], # Instantaccess
    [0.00, 0.00, 1.00], # Lolyda.AA1
    [0.00, 0.00, 0.75], # Lolyda.AA2
    [0.07, 0.32, 0.98], # Lolyda.AA3
    [0.00, 0.15, 0.86], # Lolyda.AT
    [0.00, 0.03, 0.95], # Malex.gen!J
    [0.00, 0.11, 0.04], # Obfuscator.AD
    [0.00, 0.00, 0.66], # Rbot!gen
    [0.01, 0.00, 1.00], # Skintrim.N
    [0.03, 0.00, 0.24], # Swizzor.gen!E
    [0.00, 0.77, 1.00], # Swizzor.gen!I
    [0.08, 0.00, 0.86], # VB.AT
    [0.00, 0.00, 1.00], # Wintrim.BX
    [0.00, 0.19, 0.42],  # Yuner.A
    [0.79, 0.85, 1.00]  # Yuner.A
]

pgd_data = [
    [0.28, 0.00, 1.00], # Adialer.C
    [0.00, 0.00, 0.58], # Agent.FYI
    [0.00, 0.00, 0.56], # Allaple.A
    [0.00, 0.00, 0.93], # Allaple.L
    [0.00, 0.00, 0.69], # Alueron.gen!J
    [0.00, 0.00, 0.68], # Autorun.K
    [0.00, 0.19, 0.57], # C2LOP.P
    [0.01, 0.00, 0.85], # C2LOP.gen!g
    [0.00, 0.00, 0.94], # Dialplatform.B
    [0.00, 0.00, 0.12], # Dontovo.A
    [0.00, 0.00, 0.99], # Fakerean
    [0.00, 0.00, 1.00], # Instantaccess
    [0.00, 0.00, 0.95], # Lolyda.AA1
    [0.00, 0.00, 0.70], # Lolyda.AA2
    [0.00, 0.02, 0.97], # Lolyda.AA3
    [0.00, 0.00, 0.82], # Lolyda.AT
    [0.00, 0.00, 0.85], # Malex.gen!J
    [0.00, 0.08, 0.00], # Obfuscator.AD
    [0.00, 0.00, 0.54], # Rbot!gen
    [0.00, 0.00, 0.98], # Skintrim.N
    [0.00, 0.00, 0.08], # Swizzor.gen!E
    [0.00, 0.03, 1.00], # Swizzor.gen!I
    [0.00, 0.00, 0.81], # VB.AT
    [0.00, 0.00, 1.00], # Wintrim.BX
    [0.00, 0.00, 0.33],  # Yuner.A
    [0.00, 0.50, 1.00]  # Yuner.A
]

# === SAFETY CHECK ===
# MaleVis often has 26 classes. Your data has 25 rows.
# If there is a mismatch, we truncate the class list to match the data 
# (assuming the data corresponds to the first N classes alphabetically, or that one class was excluded).
if len(class_names) != len(fgsm_data):
    print(f"⚠️  Mismatch detected: Found {len(class_names)} classes but {len(fgsm_data)} rows of data.")
    print("   Truncating/Adjusting class list to match data length for plotting.")
    class_names = class_names[:len(fgsm_data)]

# ==========================================
# PLOT CONFIGURATION
# ==========================================

plt.rcParams["font.family"] = "serif"
plt.rcParams["font.serif"] = ["Times New Roman"]
plt.rcParams["font.size"] = 10

# Create Transposed DataFrames
try:
    df_fgsm = pd.DataFrame(fgsm_data, index=class_names, columns=model_names).T
    df_pgd = pd.DataFrame(pgd_data, index=class_names, columns=model_names).T
except ValueError as e:
    print(f"Error creating DataFrame: {e}")
    print("Please check that the number of class folders matches the number of data rows.")
    exit()

# 1. Setup Figure
fig, ax = plt.subplots(2, 1, figsize=(7.5, 5.0), sharex=False)

heatmap_args = dict(
    cmap='RdYlGn', 
    annot=True, 
    fmt='.2f', 
    vmin=0, vmax=1, 
    cbar=False, 
    linewidths=0.5, 
    linecolor='white',
    annot_kws={"size": 6}
)

# Plot FGSM (Top)
sns.heatmap(df_fgsm, ax=ax[0], **heatmap_args)
ax[0].set_title('(a) Resilience under FGSM Attack', fontweight='bold', pad=3, loc='left', fontsize=9)
ax[0].set_yticklabels(ax[0].get_yticklabels(), rotation=0, fontsize=8)
ax[0].set_xticklabels([]) # Hide X labels for top

# Plot PGD (Bottom)
sns.heatmap(df_pgd, ax=ax[1], **heatmap_args)
ax[1].set_title('(b) Resilience under PGD Attack', fontweight='bold', pad=3, loc='left', fontsize=9)
ax[1].set_xlabel('Malware Family', fontweight='bold', fontsize=9)
ax[1].set_yticklabels(ax[1].get_yticklabels(), rotation=0, fontsize=8)
ax[1].set_xticklabels(df_pgd.columns, rotation=90, fontsize=8)

# === LAYOUT ADJUSTMENTS FOR RIGHT-SIDE BAR ===

# 1. Adjust margins to leave space on the RIGHT (right=0.88)
# We also use a standard bottom margin (bottom=0.25) for the labels
plt.subplots_adjust(left=0.1, right=0.88, bottom=0.25, hspace=0.4)

# 2. Add Colorbar on the Right Side
# [left, bottom, width, height]
cbar_ax = fig.add_axes([0.90, 0.25, 0.02, 0.63]) 

norm = plt.Normalize(0, 1)
sm = plt.cm.ScalarMappable(cmap="RdYlGn", norm=norm)
sm.set_array([])
cbar = fig.colorbar(sm, cax=cbar_ax, orientation='vertical') # Vertical fits "Right Side" best
cbar.set_label('F1-Score', fontsize=9)
cbar.ax.tick_params(labelsize=8)

plt.savefig('heatmap_right_bar.pdf', bbox_inches='tight', dpi=300)
print("Plot saved as 'heatmap_right_bar.pdf'")
plt.show()
# Out:
# findfont: Generic family 'serif' not found because none of the following families were found: Times New Roman
# findfont: Generic family 'serif' not found because none of the following families were found: Times New Roman
# findfont: Generic family 'serif' not found because none of the following families were found: Times New Roman
# findfont: Generic family 'serif' not found because none of the following families were found: Times New Roman
# findfont: Generic family 'serif' not found because none of the following families were found: Times New Roman
# findfont: Generic family 'serif' not found because none of the following families were found: Times New Roman
# findfont: Generic family 'serif' not found because none of the following families were found: Times New Roman
# findfont: Generic family 'serif' not found because none of the following families were found: Times New Roman
# ...
